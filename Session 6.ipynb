# %% [markdown]
# **Functions**

# %%
def greet():
    print("Hello World")

greet()
# Out:
# Hello World

# %%
def add():
    a=5
    b=6
    c=a+b
    print(c)

add()
# Out:
# 11

# %% [markdown]
# **Orgument and Parameter in Functions**

# %%
def greeting(greet):
    print(greet)

greeting("Hello! How are you ?")
# Out:
# Hello! How are you ?

# %%
def adding(a,b,c=2):
    print(a+b+c)

adding(5,7,9)
# Out:
# 21

# %%
def newAdd(a,b,c):
    print(c-b+a)
newAdd(c=10, b=6 , a =2)
# Out:
# 6

# %% [markdown]
# **Global and Loval Variable**

# %%
x = 7
def kuchBhi():
    a =5
    print(x)
    print(a)

kuchBhi()
print(a)
# Out:
# 7
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5     print(a)
#       7 kuchBhi()
# ----> 8 print(a)
#
# NameError: name 'a' is not defined
