# %%
print("Hello World")
# Out:
# Hello World

# %%
names=["Adnan","Ali","Amjad","Ahmed","Arsalan"]
print(names)
# Out:
# ['Adnan', 'Ali', 'Amjad', 'Ahmed', 'Arsalan']

# %%
print(names[2])
# Out:
# Amjad

# %%
a = ["Ali", 12 , 15.76 , True]
print(a)
# Out:
# ['Ali', 12, 15.76, True]

# %%
pet = ["cow","cat","dog","goat","camel","snake"]
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'goat', 'camel', 'snake']

# %%
pet.append("sheep")

# %%
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'goat', 'camel', 'snake', 'sheep']

# %%
pet.insert(3,"fish")

# %%
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'fish', 'goat', 'camel', 'snake', 'sheep']

# %%
pet.insert(0,"parrot")

# %%
print(pet)
# Out:
# ['parrot', 'cow', 'cat', 'dog', 'fish', 'goat', 'camel', 'snake', 'sheep']

# %%
# Slice
newPet = pet[2:5]
print(newPet)
# Out:
# ['cat', 'dog', 'fish']

# %%
pet2 = pet[3:7]
print(pet2)
# Out:
# ['dog', 'fish', 'goat', 'camel']

# %%
print(pet)
# Out:
# ['parrot', 'cow', 'cat', 'dog', 'fish', 'goat', 'camel', 'snake', 'sheep']

# %%
del pet[5]

# %%
print(pet)
# Out:
# ['parrot', 'cow', 'cat', 'dog', 'fish', 'camel', 'snake', 'sheep']

# %%
pet.remove("snake")

# %%
print(pet)
# Out:
# ['parrot', 'cow', 'cat', 'dog', 'fish', 'camel', 'sheep']

# %%
x = "Hello, My name is Muhammad Ali Mughal"

# %%
y = x.replace("My","Your")

# %%
print(y)
# Out:
# Hello, Your name is Muhammad Ali Mughal

# %%
print(pet)
# Out:
# ['parrot', 'cow', 'cat', 'dog', 'fish', 'camel', 'sheep']

# %%
pet3 = pet.pop()

# %%
print(pet3)
# Out:
# sheep

# %%
print(names)
# Out:
# ['Adnan', 'Ali', 'Amjad', 'Ahmed', 'Arsalan']

# %%
subject = ("eng","isl","maths","urdu","comp")

# %%
print(subject)
# Out:
# ('eng', 'isl', 'maths', 'urdu', 'comp')

# %%
subject.append("sindhi")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 subject.append("sindhi")
#
# AttributeError: 'tuple' object has no attribute 'append'
